# %%
import pandas as pd

# %%
url = '''https://raw.githubusercontent.com/data-visualization-society/data_visualization_survey/master/data/cleaned_survey_results_2019.csv'''
data = pd.read_csv(url)

# %%
data.shape
# Out:
# (1359, 50)

# %%
data.head()
# Out:
#   Have you studied data visualization in school (or other formal environment) or did you learn how to do it on your own?  \
# 0                 Equal Parts School and Self-Taught
# 1                                 Mostly Self-Taught
# 2                 Equal Parts School and Self-Taught
# 3                                 Mostly Self-Taught
# 4                                 Mostly Self-Taught
#
#   What methods do you think best teach data visualization?  \
# 0  Workshops, Collaboration with more skilled pra...
# 1  Workshops, Video Tutorials, Collaboration with...
# 2  Examples, Video Tutorials, Working through a p...
# 3                Examples, Working through a project
# 4                Examples, Working through a project
#
#   What area is your next priority for improving your data visualization skills?  \
# 0  Improving my skills with an existing technical...
# 1           Learning a new technical tool or library
# 2                           Improving my data skills
# 3                           Improving my data skills
# 4                           Improving my data skills
#
#   Are you a freelancer/consultant?  \
# 0                               No
# 1                               No
# 2                               No
# 3                              Yes
# 4                              Yes
#
#       What focus is data visualization in your work?  \
# 0  Data visualization is an important secondary p...
# 1          Data visualization is the focus of my job
# 2  Data visualization is one of several other thi...
# 3  Data visualization is an important secondary p...
# 4  Data visualization is an important secondary p...
#
#   For the majority of your projects: were you hired to do data visualization only or is data visualization a part of your job/project description?  \
# 0          Data visualization is only part of my job
# 1          Data visualization is only part of my job
# 2          Data visualization is only part of my job
# 3          Data visualization is only part of my job
# 4          Data visualization is only part of my job
#
#   Do you do more or less data visualization than you expected for this role?  \
# 0          About as much as I expected for this role
# 1                                               Less
# 2                                               Less
# 3          About as much as I expected for this role
# 4          About as much as I expected for this role
#
#   Which one of these is the closest to describing your role?  \
# 0                                           Academic
# 1            Leadership (Manager, Director, VP, etc)
# 2            Leadership (Manager, Director, VP, etc)
# 3            Leadership (Manager, Director, VP, etc)
# 4            Leadership (Manager, Director, VP, etc)
#
#   What is your yearly pay? What is your hourly rate?  \
# 0              $40k - $60k                    $30.00
# 1        Less than $20,000                     $5.00
# 2            $120k - $140k                       NaN
# 3            $100k - $120k                    $65.00
# 4            $100k - $120k                    $65.00
#
#                            ...                           \
# 0                          ...
# 1                          ...
# 2                          ...
# 3                          ...
# 4                          ...
#
#   Do you want to spend more time or less time visualizing data in the future?  \
# 0                                               More
# 1                                          Much more
# 2                                               More
# 3                                          Much more
# 4                                          Much more
#
#   How many years of experience do you have doing professional data visualization?  \
# 0                                                2.0
# 1                                                6.0
# 2                                                7.0
# 3                                                5.0
# 4                                                5.0
#
#   What is your educational background  \
# 0                             Masters
# 1                           Bachelors
# 2                             Masters
# 3                           Bachelors
# 4                           Bachelors
#
#   The organization you work for is in which of the following areas?  \
# 0                                           Academic
# 1                                         Journalism
# 2                                      Public sector
# 3                                          Marketing
# 4                                          Marketing
#
#   If you went to college, what did you major in during your undergraduate work?  \
# 0                                            Biology
# 1                              Public Administration
# 2                                        Mathematics
# 3                                           English!
# 4                                           English!
#
#    What's your gender identity?  \
# 0                   Genderqueer
# 1                           Man
# 2                           Man
# 3                           Man
# 4                           Man
#
#    Do you consider yourself a member of the LGBTQ+ community?   \
# 0                                                Yes
# 1                                                 No
# 2                                                 No
# 3                                                 No
# 4                                                 No
#
#    What city do you live in?  What country do you live in?  \
# 0                        NaN                           USA
# 1              Dar es Salaam                      Tanzania
# 2            Washington D.C.                           USA
# 3                   Petaluma                           USA
# 4                   Petaluma                           USA
#
#    What non-programming languages do you use regularly?
# 0                                            English
# 1                                                NaN
# 2                                                NaN
# 3                                            English
# 4                                            English
#
# [5 rows x 50 columns]

# %%
data['What technologies do you use to visualize data? Select all that apply.']
# Out:
# array(['ArcGIS, Excel, ggplot2, Gephi, Illustrator, Java, Leaflet, Mapbox, Plotly, Python, QGIS, R, Tableau, Web Components, Pen & Paper, Other physical materials, Canvas, GeoDa',
#        'Excel, Tableau, Piktochart, Venngage, Flourish',
#        'Excel, Power BI, R, Tableau, Pen & Paper, PowerPoint', ...,
#        'Excel, Power BI, Tableau, Canvas',
#        'D3, Excel, Illustrator, Python, QGIS, Pen & Paper, Raw graphs',
#        'D3, Canvas, Matplotlib'], dtype=object)

# %% [markdown]
# ## Pay based Insights

# %%
df_1 = data.rename(columns = {
        'What is your yearly pay?': 'pay',
        'What country do you live in?': 'country'
      }).groupby(
    ['country', 'pay']).agg(
    {'pay': 'count'}).rename(
    columns = {
        'pay': 'pay_count'
      }).sort_values(['country', 'pay','pay_count'], ascending=False).reset_index()

# %%
# countries with most responses;
df_2 = data.rename(columns = {
        'What country do you live in?': 'country'
      }).groupby(
    ['country']).agg(
    {'country': 'count'}).rename(columns={'country': 'response_count'}).reset_index()

# %%
temp2 = pd.merge(df_1, df_2, on='country')

pd.merge(temp, temp2, on='country').to_csv('geographical.csv', index=False)

# %%
method_dict = dict()
temp = data[data['Have you studied data visualization in school (or other formal environment) or did you learn how to do it on your own?'] == 'Mostly Self-Taught']
temp.head()
# Out:
#   Have you studied data visualization in school (or other formal environment) or did you learn how to do it on your own?  \
# 1                                 Mostly Self-Taught
# 3                                 Mostly Self-Taught
# 4                                 Mostly Self-Taught
# 5                                 Mostly Self-Taught
# 6                                 Mostly Self-Taught
#
#   What methods do you think best teach data visualization?  \
# 1  Workshops, Video Tutorials, Collaboration with...
# 3                Examples, Working through a project
# 4                Examples, Working through a project
# 5  Examples, Video Tutorials, Collaboration with ...
# 6  Books, Workshops, Examples, Video Tutorials, C...
#
#   What area is your next priority for improving your data visualization skills?  \
# 1           Learning a new technical tool or library
# 3                           Improving my data skills
# 4                           Improving my data skills
# 5                           Improving my data skills
# 6  Improving my skills with an existing technical...
#
#   Are you a freelancer/consultant?  \
# 1                               No
# 3                              Yes
# 4                              Yes
# 5                       Occasional
# 6                       Occasional
#
#       What focus is data visualization in your work?  \
# 1          Data visualization is the focus of my job
# 3  Data visualization is an important secondary p...
# 4  Data visualization is an important secondary p...
# 5  Data visualization is one of several other thi...
# 6  Data visualization is an important secondary p...
#
#   For the majority of your projects: were you hired to do data visualization only or is data visualization a part of your job/project description?  \
# 1          Data visualization is only part of my job
# 3          Data visualization is only part of my job
# 4          Data visualization is only part of my job
# 5          Data visualization is only part of my job
# 6                     Hired to do data visualization
#
#   Do you do more or less data visualization than you expected for this role?  \
# 1                                               Less
# 3          About as much as I expected for this role
# 4          About as much as I expected for this role
# 5          About as much as I expected for this role
# 6          About as much as I expected for this role
#
#   Which one of these is the closest to describing your role?  \
# 1            Leadership (Manager, Director, VP, etc)
# 3            Leadership (Manager, Director, VP, etc)
# 4            Leadership (Manager, Director, VP, etc)
# 5                                          Developer
# 6                                            Analyst
#
#   What is your yearly pay? What is your hourly rate?  \
# 1        Less than $20,000                     $5.00
# 3            $100k - $120k                    $65.00
# 4            $100k - $120k                    $65.00
# 5             $80k - $100k                    $50.00
# 6            $100k - $120k                    $80.00
#
#                            ...                           \
# 1                          ...
# 3                          ...
# 4                          ...
# 5                          ...
# 6                          ...
#
#   Do you want to spend more time or less time visualizing data in the future?  \
# 1                                          Much more
# 3                                          Much more
# 4                                          Much more
# 5                                          Much more
# 6                                          Much more
#
#   How many years of experience do you have doing professional data visualization?  \
# 1                                                6.0
# 3                                                5.0
# 4                                                5.0
# 5                                                NaN
# 6                                                8.0
#
#   What is your educational background  \
# 1                           Bachelors
# 3                           Bachelors
# 4                           Bachelors
# 5                        Some college
# 6                           Bachelors
#
#   The organization you work for is in which of the following areas?  \
# 1                                         Journalism
# 3                                          Marketing
# 4                                          Marketing
# 5                                     Private sector
# 6                                     Private sector
#
#   If you went to college, what did you major in during your undergraduate work?  \
# 1                              Public Administration
# 3                                           English!
# 4                                           English!
# 5                                   Computer Science
# 6                             Information Technology
#
#    What's your gender identity?  \
# 1                           Man
# 3                           Man
# 4                           Man
# 5                           Man
# 6                           Man
#
#    Do you consider yourself a member of the LGBTQ+ community?   \
# 1                                                 No
# 3                                                 No
# 4                                                 No
# 5                      No, but I identify as an Ally
# 6                                                 No
#
#    What city do you live in?  What country do you live in?  \
# 1              Dar es Salaam                      Tanzania
# 3                   Petaluma                           USA
# 4                   Petaluma                           USA
# 5                     Denver                           USA
# 6                    Phoenix                           USA
#
#    What non-programming languages do you use regularly?
# 1                                                NaN
# 3                                            English
# 4                                            English
# 5                                                NaN
# 6                                                NaN
#
# [5 rows x 50 columns]

# %%
for index, row in temp[['What technologies do you use to visualize data? Select all that apply.']].iterrows():
    arr = row.values[0]
    arr = arr.split(', ')
#     print(arr)
    for method in arr:
        if method not in method_dict:
            method_dict[method] = 1
        else:
            method_dict[method] += 1
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-64-59bb4a2c4470> in <module>()
#       1 for index, row in temp[['What technologies do you use to visualize data? Select all that apply.']].iterrows():
#       2     arr = row.values[0]
# ----> 3     arr = arr.split(', ')
#       4 #     print(arr)
#       5     for method in arr:
#
# AttributeError: 'float' object has no attribute 'split'

# %%
method_dict
# Out:
# {'Adobe Xd': 0,
#  'Affinity Designer': 0,
#  'Altair': 0,
#  'Alteryx': 2,
#  'Angular': 16,
#  'ArcGIS': 40,
#  'Arcadia Data': 0,
#  'BO': 0,
#  'Blender': 0,
#  'Bokeh': 1,
#  'Business Objects': 0,
#  'Canvas': 43,
#  'Cesium.js': 0,
#  'Charticulator': 0,
#  'Chartio': 0,
#  'Cognos': 0,
#  'Cytoscape': 10,
#  'Cytoscape.js': 0,
#  'D3': 198,
#  'Data Illustrator': 0,
#  'Datashader': 0,
#  'Datawrapper': 1,
#  'Domo': 0,
#  'Ember.js': 0,
#  'Excel': 298,
#  'Figma': 0,
#  'Flourish': 5,
#  'Gephi': 33,
#  'Gnuplot': 0,
#  'Google Data Studio': 2,
#  'Google Earth Engine': 0,
#  'Google Sheets': 3,
#  'Google data studio': 1,
#  'Greensock': 6,
#  'Highcharts': 41,
#  'Holoviews': 0,
#  'Igor Pro from Wavemetrics': 0,
#  'Illustrator': 104,
#  'Infogram': 1,
#  'Inkscape': 0,
#  'Java': 7,
#  'Julia': 0,
#  'Jupyter': 0,
#  'KeyLines API': 0,
#  'Kibana': 0,
#  'Knowage': 0,
#  'Leaflet': 65,
#  'Looker': 0,
#  'LucidChart': 0,
#  'Mapbox': 65,
#  'Mathematica': 0,
#  'Matlab': 2,
#  'Matplotlib': 86,
#  'Mayavi ': 0,
#  'Microstrategy': 7,
#  'Observable': 0,
#  'Omnigraffle': 0,
#  'OpenLayers': 0,
#  'Other physical materials': 13,
#  'P5/Processing': 15,
#  'Pen & Paper': 143,
#  'Piktochart': 0,
#  'Plotly': 107,
#  'Power BI': 99,
#  'PowerPoint': 1,
#  'Processing': 16,
#  'Python': 225,
#  'QGIS': 67,
#  'Qlik': 18,
#  'R': 218,
#  'RAW': 0,
#  'Raw': 0,
#  'Raw Graphs': 0,
#  'RawGraphs.io': 0,
#  'React': 57,
#  'Recharts': 0,
#  'SAP BO': 1,
#  'SAP Business Objects': 0,
#  'SAP WebI': 0,
#  'SAS': 0,
#  'SVG': 0,
#  'Salesforce': 0,
#  'Sas ': 0,
#  'Seaborn': 3,
#  'Semiotic': 9,
#  'ShowMyData.org': 0,
#  'Sketch': 0,
#  'Smalltalk': 0,
#  'Spotfire': 1,
#  'Stata / SAS': 0,
#  'Tableau': 236,
#  'Think-cell': 0,
#  'ThoughtSpot': 0,
#  'Tibco Spotfire': 0,
#  'Turf.js': 0,
#  'Ucinet/Netdraw': 0,
#  'Unity': 0,
#  'Unity3D ': 0,
#  'Vega': 29,
#  'Venngage': 0,
#  'Vue': 23,
#  'Web Components': 19,
#  'WebGL': 48,
#  'Yellowbrick ': 0,
#  'ZingChart & ZingGrid': 0,
#  'altair': 0,
#  'altair (python)': 0,
#  'amCharts': 0,
#  'aplpy': 0,
#  'bokeh': 1,
#  'deck.gl': 0,
#  'decksh': 0,
#  'elm-visualization': 0,
#  'geoviews': 0,
#  'ggplot2': 190,
#  'ggvis': 0,
#  'grid': 0,
#  'hand drawn with adobe Director': 0,
#  'holoview': 0,
#  'holoviews': 0,
#  'hvplot': 0,
#  'kepler.gl': 17,
#  'lattice': 0,
#  'libre office': 0,
#  'matplotlib': 0,
#  'nglview': 0,
#  'other bi tools': 0,
#  'pixi.js': 0,
#  'plotnine': 0,
#  'pyviz': 0,
#  'react-vis': 0,
#  'seaborn': 1,
#  'tabX': 0,
#  'vmd': 0}

# %%
237-142
# Out:
# 95
